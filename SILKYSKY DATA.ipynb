# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("SILKYSKY_DATA_CW2 (F).csv", encoding='latin1')
import pandas as pd

# Read CSV with 'latin1' encoding and first column as index
data = pd.read_csv("SILKYSKY_DATA_CW2 (F).csv", encoding='latin1', index_col=0)

data.head()
# Out:
#          id  Gender Satisfied  Age  Age Band   Type of Travel     Class  \
# Ref
# 0     70172    Male         Y   13  Under 18  Personal Travel  Eco Plus
# 1      5047    Male         N   25  25 to 34  Business travel  Business
# 2    110028  Female         Y   26  25 to 34  Business travel  Business
# 3     24026  Female         Y   25  25 to 34  Business travel  Business
# 4    119299    Male         Y   61  55 to 64  Business travel  Business
#
#      Flight Distance          Destination Continent  ...  Seat comfort  \
# Ref                                                  ...
# 0               4760                India      Asia  ...             5
# 1                235  Republic of Ireland    Europe  ...             1
# 2               4760                India      Asia  ...             5
# 3                560               Norway    Europe  ...             2
# 4               4760                India      Asia  ...             5
#
# ...

# %%
data
# Out:
#             id  Gender Satisfied  Age  Age Band   Type of Travel     Class  \
# Ref
# 0        70172    Male         Y   13  Under 18  Personal Travel  Eco Plus
# 1         5047    Male         N   25  25 to 34  Business travel  Business
# 2       110028  Female         Y   26  25 to 34  Business travel  Business
# 3        24026  Female         Y   25  25 to 34  Business travel  Business
# 4       119299    Male         Y   61  55 to 64  Business travel  Business
# ...        ...     ...       ...  ...       ...              ...       ...
# 103899   94171  Female         N   23  18 to 24  Business travel       Eco
# 103900   73097    Male         Y   49  45 to 54  Business travel  Business
# 103901   68825    Male         N   30  25 to 34  Business travel  Business
# 103902   54173  Female         N   22  18 to 24  Business travel       Eco
# 103903   62567    Male         Y   27  25 to 34  Business travel  Business
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103904 entries, 0 to 103903
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Satisfied                          103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Age Band                           103904 non-null  object
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Destination                        103904 non-null  object
#  9   Continent                          103904 non-null  object
#  10  Inflight wifi service              103904 non-null  int64
# ...

# %%
data.shape
# Out:
# (103904, 26)

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Satisfied', 'Age', 'Age Band', 'Type of Travel',
#        'Class', 'Flight Distance', 'Destination', 'Continent',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Ease of Online booking', 'Gate location', 'Food and drink',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Inflight service', 'Cleanliness',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      4164.071066               2.522319
# std     37463.812252      15.114964      1346.755749               1.447848
# min         1.000000       7.000000       235.000000               0.000000
# 25%     32533.750000      27.000000      4760.000000               1.000000
# 50%     64856.500000      40.000000      4760.000000               3.000000
# 75%     97368.250000      51.000000      4760.000000               4.000000
# max    129880.000000      85.000000      5940.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060248                2.756852
# std                             1.525143                1.398993
# ...

# %%
data.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Satisfied                              0
# Age                                    0
# Age Band                               0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Destination                            0
# Continent                              0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# ...

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Satisfied                            0
# Age                                  0
# Age Band                             0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Destination                          0
# Continent                            0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# ...

# %% [markdown]
# # Visualization

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 5)

# %% [markdown]
# # 1. Satisfaction by Gender - Bar Chart

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Satisfied', 'Age', 'Age Band', 'Type of Travel',
#        'Class', 'Flight Distance', 'Destination', 'Continent',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Ease of Online booking', 'Gate location', 'Food and drink',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Inflight service', 'Cleanliness',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
satisfaction_gender = data.groupby(['Gender', 'Satisfied']).size().unstack()
satisfaction_gender.plot(kind='bar', stacked=True)
plt.title("Satisfaction by Gender")
plt.xlabel("Gender")
plt.ylabel("count")
plt.legend(title= "Satisfied")
plt.show()

# %% [markdown]
# # 2. Satisfaction by Age Band - Bar Chart

# %%
satisfaction_ageband =data.groupby(['Age Band', 'Satisfied']).size().unstack()
satisfaction_ageband.plot(kind='bar', stacked=True)
plt.title("Satisfaction by Age Band")
plt.xlabel("Age Band")
plt.ylabel("count")
plt.legend(title= "Satisfied")
plt.show()

# %% [markdown]
# # 3. Satisfaction vs Flight Distance - Scatter Plot

# %%
colors = {'Y' : 'green', 'N' : 'red'}
plt.scatter(data['Flight Distance'],data['Age'], c=data['Satisfied'].map(colors), alpha=0.5)
plt.title("Satisfaction vs Flight Distance")
plt.xlabel("Flight Distance")
plt.ylabel("Age")
plt.grid(True)
plt.show()

# %% [markdown]
# # 4. Type of Travel vs Class vs Satisfaction - Stacked Bar Chart

# %%
grouped = data.groupby(['Type of Travel', 'Class', 'Satisfied']).size().unstack().unstack()
grouped.plot(kind='bar', stacked=True)
plt.title("Satisfaction by Travel Type and Class")
plt.xlabel("Type of Travel / Class")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Satisfied")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Service Scores vs Satisfaction - Box Plots

# %%
service_cols = ['Seat comfort', 'Inflight entertainment', 'On-board service',
                'Leg room service', 'Baggage handling', 'Checkin service',
                'Inflight service', 'Cleanliness']

for col in service_cols:
    sns.boxplot(data=data, x='Satisfied', y=col)
    plt.title(f"{col} by Satisfaction")
    plt.show()

# Optional: Violin Plot for visual smoothness
for col in service_cols:
    sns.violinplot(data=data, x='Satisfied', y=col, inner='quartile')
    plt.title(f"{col} by Satisfaction (Violin Plot)")
    plt.show()
